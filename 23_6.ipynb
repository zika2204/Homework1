# %%
# !pip install osmnx networkx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.6.1)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.3)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.30 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (26.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)
# Downloading osmnx-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.1.0

# %%
import folium
from geopy.geocoders import Nominatim
import osmnx as ox
import networkx as nx
nha = "52 Vo Liem Son, Ho Chi Minh City"
geolocator = Nominatim(user_agent="my_app")
nha1 = geolocator.geocode(nha)
toado_nha = (nha1.latitude, nha1.longitude)
m = folium.Map(location=toado_nha, zoom_start=17)
folium.Marker(location=toado_nha, popup=nha).add_to(m)
ox.settings.timeout = 300
ox.settings.use_cache = True
ox.settings.log_console = True
G = ox.graph_from_point(toado_nha, dist=100, network_type="walk")
stats = ox.basic_stats(G)
print(f"--- Kết quả phân tích ---")
print(f"Số nút giao: {stats['n']}")
print(f"Số đoạn đường: {stats['m']}")
print(f"Chiều dài trung bình: {stats['street_length_avg']:.2f}m")
nodes, edges = ox.graph_to_gdfs(G)
folium.GeoJson(edges).add_to(m)
m
# Out:
# --- Kết quả phân tích ---
# Số nút giao: 21
# Số đoạn đường: 54
# Chiều dài trung bình: 31.61m
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76fac87de79cd571052fb84f1fa41dff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76fac87de79cd571052fb84f1fa41dff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76fac87de79cd571052fb84f1fa41dff = L.map(
#                 &quot;map_76fac87de79cd571052fb84f1fa41dff&quot;,
#                 {
#                     center: [10.7371309, 106.6755775],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b04785ddd51d73b7c3be0fb4e703a3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b04785ddd51d73b7c3be0fb4e703a3e.addTo(map_76fac87de79cd571052fb84f1fa41dff);
#
#
#             var marker_a573a9adb137ece80f6ff6ca36e33caa = L.marker(
#                 [10.7371309, 106.6755775],
#                 {
# }
#             ).addTo(map_76fac87de79cd571052fb84f1fa41dff);
#
#
#         var popup_f7c52665ae67f6ee7614dedc75caad59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd3896f97de08d600028e1acda2025d1 = $(`&lt;div id=&quot;html_bd3896f97de08d600028e1acda2025d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;52 Vo Liem Son, Ho Chi Minh City&lt;/div&gt;`)[0];
#                 popup_f7c52665ae67f6ee7614dedc75caad59.setContent(html_bd3896f97de08d600028e1acda2025d1);
#
#
#
#         marker_a573a9adb137ece80f6ff6ca36e33caa.bindPopup(popup_f7c52665ae67f6ee7614dedc75caad59)
#         ;
#
#
#
#
#
#         function geo_json_bbb95b6bb33af754c4ebf375649e3d80_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_bbb95b6bb33af754c4ebf375649e3d80 = L.geoJson(null, {
#                 onEachFeature: geo_json_bbb95b6bb33af754c4ebf375649e3d80_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_bbb95b6bb33af754c4ebf375649e3d80_add (data) {
#             geo_json_bbb95b6bb33af754c4ebf375649e3d80
#                 .addData(data);
#         }
#             geo_json_bbb95b6bb33af754c4ebf375649e3d80_add({&quot;bbox&quot;: [106.6748615, 10.736381, 106.6763988, 10.7377245], &quot;features&quot;: [{&quot;bbox&quot;: [106.6752762, 10.7373218, 106.6754827, 10.7377245], &quot;geometry&quot;: {&quot;coordinates&quot;: [[106.6752762, 10.7377245], [106.6754827, 10.7373218]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1757002979, 1757008360, 0)&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;residential&quot;, &quot;length&quot;: 50.14015117781636, &quot;name&quot;: &quot;V\u00f5 Li\u00eam S\u01a1n&quot;, &quot;oneway&quot;: false, &quot;osmid&quot;: 164040174, &quot;reversed&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [106.6754827, 10.7368358, 106.675724, 10.7373218], &quot;geometry&quot;: {&quot;coordinates&quot;: [[106.6754827, 10.7373218], [106.675724, 10.7368358]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1757008360, 6437798039, 0)&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;residential&quot;, &quot;length&quot;: 60.12773337585882, &quot;name&quot;: &quot;V\u00f5 Li\u00eam S\u01a1n&quot;, &quot;oneway&quot;: false, &quot;osmid&quot;: 164040174, &quot;reversed&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [106.6752762, 10.7373218, 106.6754827, 10.7377245], &quot;geometry&quot;: {&quot;coordinates&quot;: [[106.6754827, 10.7373218], [106.6752762, 10.7377245]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1757008360, 1757002979, 0)&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;residential&quot;, &quot;length&quot;: 50.14015117781636, &quot;name&quot;: &quot;V\u00f5 Li\u00eam S\u01a1n&quot;, &quot;oneway&quot;: false, &quot;osmid&quot;: 164040174, &quot;reversed&quot;: true}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [106.6750606, 10.7370899, 106.6754827, 10.7373218], &quot;geometry&quot;: {&quot;coordinates&quot;: [[106.6754827, 10.7373218], [106.6750606, 10.7370899]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;(1757008360, 3232855071, 0)&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;residential&quot;, &quot;length&quot;: 52.833685825877275, &quot;name&quot;: &quot;Ch\u00e2u Th\u1ecb H\u00f3a&quot;, &quot;oneway&quot;: false, &quot;osmid&quot;: 164040625, &quot;reversed&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [106.6754827, 10.7373218, 106.6758352, 10.7374962], &quot;geometry&quot;: {&quot;coordin
